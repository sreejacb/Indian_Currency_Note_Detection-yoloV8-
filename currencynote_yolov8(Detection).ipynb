# %% [markdown]
# ## **Importing** **Libraries**

# %%
# !pip install opencv-python

# %% [markdown]
# ## **Loading dataset directly from roboflow**

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="I7qxdUq9lAbyNjivlTqo")
# project = rf.workspace("yolov5-gjdpm").project("indian-currency-note-by-harshit-kumar")
# dataset = project.version(2).download("yolov8")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="I7qxdUq9lAbyNjivlTqo")
project = rf.workspace("ml-project-d0vep").project("indian-currency-detection-elfyf")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
# ...

# %% [markdown]
# ## **training YOLOv8 model**

# %%
! pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.6/615.6 kB 9.1 MB/s eta 0:00:00
# ...

# %%
# train the model

from ultralytics import YOLO
model = YOLO()
#model YOLO("yolov8n.pt") # Load a pretrained YOLOV8n model
model.train(data= r"/content/Indian-Currency-Detection--2/data.yaml", epochs=100) # train the model
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# model validation(accuracy graph)

# !yolo task=detect mode=val model= "/content/runs/detect/train2/weights/best.pt" data= "/content/Indian-Currency-Detection--2/data.yaml"
# Out:
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients
# val: Scanning /content/Indian-Currency-Detection--2/valid/labels.cache... 118 images, 0 backgrounds, 0 corrupt: 100% 118/118 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 77, len(boxes) = 128. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.19s/it]
#                    all        118        128      0.915      0.906      0.945      0.795
#                     10        118         17          1      0.917      0.987      0.848
#                    100        118         30      0.932      0.933      0.959      0.873
# ...

# %%
# testing( with image or video uploading)

# !yolo task=detect mode=predict model= "/content/runs/detect/train2/weights/best.pt" show=True conf=0.5 source = "/content/notevideo.mp4"
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients
#
# video 1/1 (1/844) /content/notevideo.mp4: 640x384 (no detections), 55.1ms
# video 1/1 (2/844) /content/notevideo.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (3/844) /content/notevideo.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (4/844) /content/notevideo.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (5/844) /content/notevideo.mp4: 640x384 (no detections), 5.9ms
# video 1/1 (6/844) /content/notevideo.mp4: 640x384 (no detections), 6.1ms
# video 1/1 (7/844) /content/notevideo.mp4: 640x384 1 10, 5.8ms
# video 1/1 (8/844) /content/notevideo.mp4: 640x384 (no detections), 8.9ms
# video 1/1 (9/844) /content/notevideo.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (10/844) /content/notevideo.mp4: 640x384 (no detections), 5.9ms
# ...
